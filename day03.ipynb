# %%
print ("Good morning")
# Out:
# Good morning

# %%
259%4
# Out:
# 3

# %%
2**8
# Out:
# 256

# %%
10//7
# Out:
# 1

# %%
x=45

# %%
x*0.1
# Out:
# 4.5

# %%
int(x)
# Out:
# 45

# %%
complex(67,78)
# Out:
# (67+78j)

# %%
num1=45
num2=56
num1==num2
# Out:
# False

# %%
num1!=num2
# Out:
# True

# %%
num1<=num2
# Out:
# True

# %%
abs(56)
# Out:
# 56

# %%
x= Notye
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x= Notye
#
# NameError: name 'Notye' is not defined

# %%
x.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 x.lower()
#
# AttributeError: 'int' object has no attribute 'lower'

# %%
email = "qwerty@mail.com"
email.endswith("skill.com")
# Out:
# False

# %%
address=("shekhar") 
address[5]
# Out:
# 'a'

# %%
len(address)
# Out:
# 7

# %%
address[-6]
# Out:
# 'h'

# %%
address[2:-3:5]
# Out:
# 'e'

# %%
address[-6:-4]
# Out:
# 'he'

# %%
address[::-1]
# Out:
# 'rahkehs'
